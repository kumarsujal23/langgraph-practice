# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model=ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# The distance from the Earth to the Moon is not constant because the Moon orbits the Earth in an ellipse, not a perfect circle.
#
# Here are the typical figures:
#
# *   **Average Distance:** Approximately **384,400 kilometers** (km) or about **238,900 miles**.
# *   **Closest (Perigee):** Around **363,104 km** or about **225,623 miles**.
# *   **Farthest (Apogee):** Around **406,696 km** or about **252,694 miles**.
#
# Therefore, while the average is often cited, the actual distance varies significantly throughout the month.
