# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model=ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state['outline'])
print('###########################################################################################')
print(final_state['content'])
# Out:
# Here's a detailed outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and well-structured.
#
# ---
#
# ## Blog Title Ideas:
# *   **From Silicon Valley to Silicon Bharat: India's AI Ascendancy**
# *   **Decoding India's AI Boom: Opportunities, Challenges, and the Road Ahead**
# *   **The AI Wave: How India is Redefining the Future of Artificial Intelligence**
# *   **India's AI Revolution: Powering Growth, Transforming Lives**
# *   **Beyond the Hype: Understanding India's Strategic Push in Artificial Intelligence**
#
# ---
#
# ## Blog Outline: The Rise of AI in India
#
# **Target Audience:** Tech enthusiasts, business professionals, policymakers, students, and anyone interested in India's technological advancements.
#
# **Tone:** Informative, optimistic but balanced, analytical, forward-looking.
#
# ---
#
# ### I. Catchy Title (Chosen from above or similar)
#
# ### II. Introduction (Approx. 150-200 words)
#
# *   **A. Hook:** Start with a compelling statistic or a thought-provoking statement about the global AI landscape and India's emerging role.
#     *   *Example:* "While the world buzzes about AI's transformative power, a quiet revolution is taking root in India, poised to reshape not just its own economy but the global tech paradigm."
# *   **B. Brief Definition of AI:** A concise, accessible explanation of what AI is (machine learning, deep learning, natural language processing) for a general audience.
# *   **C. Thesis Statement:** India is rapidly emerging as a global AI powerhouse, driven by unique advantages, strategic initiatives, and a burgeoning ecosystem, impacting diverse sectors while navigating critical challenges.
# *   **D. What the Blog Will Cover:** Briefly outline the key areas to be explored (drivers, impact, challenges, future).
#
# ### III. India's Unique AI Advantage: Why India is Poised for AI Leadership (Approx. 250-300 words)
#
# *   **A. Massive Talent Pool:**
#     *   Large number of STEM graduates (engineers, data scientists).
#     *   English proficiency facilitating global collaboration.
#     *   Strong analytical and problem-solving skills.
#     *   Growing ecosystem of specialized AI/ML courses.
# *   **B. Digital Public Infrastructure (DPI):**
#     *   **Jandhan-Aadhaar-Mobile (JAM) Trinity:** Foundation for digital identity and financial inclusion.
#     *   **Unified Payments Interface (UPI):** Massive data generation, digital payment adoption.
#     *   **Open Network for Digital Commerce (ONDC):** Democratizing e-commerce and generating valuable data.
# *   **C. Abundance of Data:**
#     *   Second-largest internet user base.
#     *   Diverse linguistic data (opportunity for NLP in Indian languages).
#     *   Data from vast consumer base across various sectors.
# *   **D. Cost-Effectiveness:**
#     *   Lower operational costs for R&D and deployment compared to Western counterparts.
#     *   Attracting global companies to set up AI development centers.
# *   **E. Entrepreneurial Spirit & Startup Ecosystem:**
#     *   Booming startup landscape, particularly in deep tech and AI.
#     *   Growth of incubators, accelerators, and venture capital funding.
#
# ### IV. Key Drivers and Enablers of India's AI Growth (Approx. 300-350 words)
#
# *   **A. Government Initiatives & Policy Support:**
#     *   **NITI Aayog's "AI for All" Strategy:** Focus on inclusive AI application.
#     *   **National AI Portal (indiaai.gov.in):** Central hub for AI development, research, and news.
#     *   **MeitY (Ministry of Electronics and Information Technology) Initiatives:** Promoting AI research, skill development, and ethical guidelines.
#     *   **Focus on Public Sector Applications:** AI in governance, smart cities, public services.
# *   **B. Burgeoning Startup Ecosystem:**
#     *   Number of AI startups and their rapid growth.
#     *   Examples of successful Indian AI startups (e.g., in FinTech, HealthTech, AgriTech).
#     *   Increased venture capital and private equity investments in AI.
# *   **C. Corporate Adoption & Investment:**
#     *   Major Indian IT services companies (TCS, Infosys, Wipro, HCLTech) investing heavily in AI capabilities and services.
#     *   Conglomerates like Reliance (Jio Platforms) leveraging AI for diverse consumer services.
#     *   Global tech giants (Google, Microsoft, Amazon) expanding AI R&D in India.
# *   **D. Academic & Research Push:**
#     *   Leading institutions (IITs, IISc, IIITs) establishing dedicated AI research centers.
#     *   Collaborations between academia, industry, and government for R&D.
#     *   Growth of AI-focused educational programs and certifications.
#
# ### V. AI's Transformative Impact Across Key Indian Sectors (Approx. 400-450 words)
#
# *   **A. Healthcare:**
#     *   **Diagnostics:** AI-powered tools for early disease detection (e.g., retinal scans for diabetes, cancer screening).
#     *   **Drug Discovery & Development:** Accelerating research.
#     *   **Personalized Medicine:** Tailored treatments based on genetic data.
#     *   **Telemedicine & Remote Monitoring:** Bridging urban-rural healthcare gaps.
# *   **B. Agriculture:**
#     *   **Precision Farming:** Crop yield prediction, soil analysis, water management.
#     *   **Pest & Disease Detection:** Early identification to prevent crop loss.
#     *   **Supply Chain Optimization:** Reducing waste, improving market access for farmers.
# *   **C. Finance (FinTech):**
#     *   **Fraud Detection & Risk Management:** Enhancing security and compliance.
#     *   **Personalized Banking & Investment Advice:** Robo-advisors, customized products.
#     *   **Credit Scoring for Underserved Populations:** Leveraging alternative data.
# *   **D. Education:**
#     *   **Personalized Learning Paths:** Adaptive content delivery.
#     *   **Automated Grading & Feedback:** Reducing teacher workload.
#     *   **Smart Content Creation:** Generating educational materials.
# *   **E. Manufacturing & Logistics:**
#     *   **Predictive Maintenance:** Reducing downtime, optimizing operations.
#     *   **Supply Chain Optimization:** Real-time tracking, demand forecasting.
#     *   **Automation & Robotics:** Enhancing efficiency and safety.
# *   **F. Customer Service & Retail:**
#     *   **Chatbots & Virtual Assistants:** Improving customer experience, 24/7 support.
#     *   **Personalized Recommendations:** Enhancing e-commerce.
#     *   **Inventory Management:** Optimizing stock levels.
# *   **G. Smart Cities & Governance:**
#     *   **Traffic Management:** Optimizing flow, reducing congestion.
#     *   **Public Safety & Surveillance:** Enhancing security.
#     *   **Waste Management & Environmental Monitoring.**
#
# ### VI. Challenges and Considerations (Approx. 200-250 words)
#
# *   **A. Data Privacy & Security:**
#     *   Need for robust data protection laws (e.g., Digital Personal Data Protection Act).
#     *   Ensuring ethical handling of vast amounts of personal data.
# *   **B. Ethical AI & Bias:**
#     *   Addressing algorithmic bias in data and models.
#     *   Ensuring fairness, transparency, and accountability in AI systems.
# *   **C. Job Displacement & Skilling Gap:**
#     *   Potential for automation to displace certain jobs.
#     *   Urgent need for upskilling and reskilling the workforce for AI-era jobs.
#     *   Bridging the gap between academic curriculum and industry demands.
# *   **D. Infrastructure Gaps:**
#     *   Uneven access to high-speed internet in rural areas.
#     *   Need for more robust computational infrastructure (e.g., cloud computing, data centers).
# *   **E. Regulatory Framework:**
#     *   Developing agile and forward-looking regulations that foster innovation while ensuring safety and ethics.
#     *   Harmonizing national and international AI policies.
# *   **F. Digital Divide:**
#     *   Ensuring AI benefits reach all segments of society, not just urban centers.
#     *   Addressing language barriers in AI applications.
#
# ### VII. The Road Ahead: India's AI Future (Approx. 150-200 words)
#
# *   **A. Global AI Leadership:** India's potential to become a major AI innovation hub and exporter of AI solutions.
# *   **B. "AI for Social Good":** Continued focus on leveraging AI to solve India's unique socio-economic challenges (e.g., poverty, healthcare access, education).
# *   **C. Enhanced Collaboration:** Strengthening ties between government, industry, academia, and international partners.
# *   **D. Continuous Talent Development:** Investing in advanced AI research and specialized skill-building programs.
# *   **E. Responsible Innovation:** Emphasizing the development and deployment of ethical, secure, and inclusive AI.
#
# ### VIII. Conclusion (Approx. 100-150 words)
#
# *   **A. Recap:** Briefly summarize India's unique advantages, the breadth of AI's impact, and the critical challenges being addressed.
# *   **B. Reiterate Thesis:** Reaffirm India's significant and growing role in the global AI landscape.
# *   **C. Final Thought/Call to Action:**
#     *   *Example:* "The rise of AI in India is not merely a technological trend; it's a national endeavor with the potential to uplift millions, drive unprecedented economic growth, and position India as a responsible leader in the global AI era. The journey has just begun, and the world watches with anticipation."
#     *   Encourage readers to share their thoughts on India's AI journey.
#
# ---
#
# This detailed outline provides a robust framework for a comprehensive and engaging blog post on the rise of AI in India, ensuring all key aspects are covered logically and thoroughly.
# ###########################################################################################
# ## India's AI Revolution: Powering Growth, Transforming Lives
#
# **I. Introduction**
#
# While the world buzzes about AI's transformative power, a quiet revolution is taking root in India, poised to reshape not just its own economy but the global tech paradigm. From bustling metropolises to remote villages, the tendrils of Artificial Intelligence are reaching into every facet of life, promising unprecedented efficiencies and solutions. At its core, AI is the science of teaching machines to think, learn, and solve problems much like humans do, encompassing fields like machine learning (ML), deep learning, and natural language processing (NLP). These technologies empower systems to analyze vast datasets, recognize patterns, make predictions, and even generate creative content.
#
# This blog delves into how India is rapidly emerging as a global AI powerhouse, driven by unique advantages, strategic initiatives, and a burgeoning ecosystem. We will explore the key drivers behind this ascendance, the profound impact AI is having across diverse Indian sectors, and the critical challenges that must be navigated to ensure an inclusive and ethical AI future.
#
# **II. India's Unique AI Advantage: Why India is Poised for AI Leadership**
#
# India's journey towards AI leadership isn't accidental; it's built upon a foundation of distinct advantages that few other nations possess.
#
# *   **A. Massive Talent Pool:** India boasts one of the world's largest pools of STEM (Science, Technology, Engineering, and Mathematics) graduates, producing millions of engineers, data scientists, and IT professionals annually. This demographic dividend is further amplified by a high degree of English proficiency, facilitating seamless collaboration with global tech giants and research institutions. Indian professionals are renowned for their strong analytical and problem-solving skills, honed by a competitive educational system. Furthermore, a growing ecosystem of specialized AI/ML courses and certifications is continuously upgrading this talent pool to meet advanced industry demands.
#
# *   **B. Digital Public Infrastructure (DPI):** India's visionary Digital Public Infrastructure (DPI) provides an unparalleled data-rich environment for AI development. The **Jandhan-Aadhaar-Mobile (JAM) Trinity** has created a foundational layer for digital identity and financial inclusion, linking over a billion people to digital services. The **Unified Payments Interface (UPI)** has revolutionized digital payments, processing billions of transactions monthly and generating an immense volume of real-time financial data. More recently, the **Open Network for Digital Commerce (ONDC)** is democratizing e-commerce, further expanding the data landscape by bringing more businesses and consumers online. This DPI serves as a fertile ground for training AI models on real-world, diverse data at an unprecedented scale.
#
# *   **C. Abundance of Data:** With the second-largest internet user base globally, India generates an enormous amount of digital data daily. This includes diverse linguistic data, presenting a unique opportunity for developing advanced NLP models tailored for Indian languages, which are often underserved by global AI solutions. Data from its vast consumer base across various sectors – from retail and healthcare to agriculture and finance – provides invaluable insights for creating localized and relevant AI applications.
#
# *   **D. Cost-Effectiveness:** India offers significantly lower operational costs for AI research, development, and deployment compared to Western counterparts. This cost advantage makes India an attractive destination for global companies seeking to establish AI development centers and for startups to innovate without prohibitive capital expenditure, fostering a vibrant and competitive AI ecosystem.
#
# *   **E. Entrepreneurial Spirit & Startup Ecosystem:** India's startup landscape is booming, with a particular surge in deep tech and AI-focused ventures. This entrepreneurial spirit is supported by a growing network of incubators, accelerators, and a robust venture capital funding environment, which are actively investing in next-generation AI solutions. This creates a dynamic environment for rapid innovation and the commercialization of AI technologies.
#
# **III. Key Drivers and Enablers of India's AI Growth**
#
# The rapid ascent of AI in India is propelled by a concerted effort from multiple stakeholders, creating a synergistic environment for innovation and adoption.
#
# *   **A. Government Initiatives & Policy Support:** The Indian government has recognized AI as a strategic imperative. **NITI Aayog's "AI for All" Strategy** emphasizes leveraging AI for inclusive growth and addressing societal challenges. The **National AI Portal (indiaai.gov.in)** serves as a central hub for AI development, research, and news, fostering collaboration and knowledge sharing. The **Ministry of Electronics and Information Technology (MeitY)** actively promotes AI research, skill development, and the formulation of ethical guidelines. There's a strong focus on public sector applications, with AI being integrated into governance, smart cities, and various public services to improve efficiency and delivery.
#
# *   **B. Burgeoning Startup Ecosystem:** India's AI startup scene is vibrant and rapidly expanding. Thousands of AI startups are emerging, specializing in everything from FinTech and HealthTech to AgriTech and EdTech. These agile companies are often at the forefront of applying AI to solve specific Indian problems. Increased venture capital and private equity investments are fueling this growth, allowing these startups to scale rapidly and bring innovative AI solutions to market.
#
# *   **C. Corporate Adoption & Investment:** Major Indian IT services companies like TCS, Infosys, Wipro, and HCLTech are investing heavily in building their AI capabilities, offering AI-powered solutions to global clients, and integrating AI into their core services. Indian conglomerates, such as Reliance Industries (through Jio Platforms), are leveraging AI to enhance their diverse consumer services, from digital content to retail. Global tech giants like Google, Microsoft, and Amazon are also significantly expanding their AI R&D centers and operations in India, tapping into the talent pool and market potential.
#
# *   **D. Academic & Research Push:** India's premier educational institutions, including the Indian Institutes of Technology (IITs), Indian Institute of Science (IISc), and various International Institutes of Information Technology (IIITs), are establishing dedicated AI research centers and labs. These institutions are fostering cutting-edge research, often in collaboration with industry and government. The growth of AI-focused educational programs, specialized degrees, and professional certifications is ensuring a continuous supply of highly skilled AI professionals.
#
# **IV. AI's Transformative Impact Across Key Indian Sectors**
#
# AI is not just a technological advancement in India; it's a catalyst for socio-economic transformation, impacting a wide array of sectors.
#
# *   **A. Healthcare:** AI is revolutionizing healthcare delivery, especially in a country with significant urban-rural disparities.
#     *   **Diagnostics:** AI-powered tools are enabling early and accurate disease detection, from analyzing retinal scans for diabetic retinopathy to assisting in cancer screening (e.g., detecting anomalies in X-rays and MRIs).
#     *   **Drug Discovery & Development:** AI is accelerating the complex process of identifying potential drug candidates and predicting their efficacy, significantly reducing time and cost.
#     *   **Personalized Medicine:** By analyzing genetic data and patient histories, AI can help tailor treatments and medication dosages for individual patients.
#     *   **Telemedicine & Remote Monitoring:** AI-driven platforms are bridging urban-rural healthcare gaps, allowing remote consultations and continuous monitoring of patients' vital signs, crucial for chronic disease management.
#
# *   **B. Agriculture:** For a country where a significant portion of the population relies on agriculture, AI offers solutions to age-old challenges.
#     *   **Precision Farming:** AI models analyze satellite imagery, weather data, and soil conditions to provide farmers with crop yield predictions, optimize irrigation, and recommend precise fertilizer application.
#     *   **Pest & Disease Detection:** Drones equipped with AI cameras can identify early signs of pest infestations or crop diseases, allowing for timely intervention and preventing widespread crop loss.
#     *   **Supply Chain Optimization:** AI helps farmers connect directly with markets, reduce post-harvest waste, and optimize logistics, ensuring better prices and timely delivery.
#
# *   **C. Finance (FinTech):** India's booming FinTech sector is a prime example of AI's transformative power.
#     *   **Fraud Detection & Risk Management:** AI algorithms analyze transaction patterns in real-time to detect fraudulent activities and assess credit risk more accurately, enhancing security and compliance.
#     *   **Personalized Banking & Investment Advice:** Robo-advisors powered by AI offer customized investment strategies, while AI-driven chatbots provide 24/7 customer support and personalized banking products.
#     *   **Credit Scoring for Underserved Populations:** By leveraging alternative data sources (e.g., mobile usage, utility payments), AI is enabling credit scoring for millions who lack traditional credit histories, fostering greater financial inclusion.
#
# *   **D. Education:** AI is making education more accessible, personalized, and engaging.
#     *   **Personalized Learning Paths:** AI platforms adapt content delivery based on a student's learning style, pace, and performance, creating customized learning experiences.
#     *   **Automated Grading & Feedback:** AI tools can automate the grading of assignments and provide instant, constructive feedback, reducing teacher workload and allowing them to focus on individualized student attention.
#     *   **Smart Content Creation:** AI can assist in generating educational materials, quizzes, and interactive lessons, making learning more dynamic.
#
# *   **E. Manufacturing & Logistics:** AI is optimizing industrial processes and supply chains.
#     *   **Predictive Maintenance:** AI analyzes sensor data from machinery to predict potential failures, allowing for proactive maintenance and significantly reducing downtime and operational costs.
#     *   **Supply Chain Optimization:** Real-time tracking, demand forecasting, and route optimization powered by AI improve efficiency, reduce delays, and minimize inventory costs.
#     *   **Automation & Robotics:** AI-driven robots are enhancing efficiency, precision, and safety in manufacturing plants, taking on repetitive or hazardous tasks.
#
# *   **F. Customer Service & Retail:** AI is redefining customer interactions and retail experiences.
#     *   **Chatbots & Virtual Assistants:** AI-powered chatbots provide instant, 24/7 customer support, resolving queries, and improving satisfaction across various industries.
#     *   **Personalized Recommendations:** E-commerce platforms use AI to analyze browsing and purchase history, offering highly personalized product recommendations that boost sales and customer engagement.
#     *   **Inventory Management:** AI optimizes stock levels, predicts demand fluctuations, and streamlines warehouse operations, reducing waste and ensuring product availability.
#
# *   **G. Smart Cities & Governance:** AI is instrumental in building more efficient and livable urban environments.
#     *   **Traffic Management:** AI systems analyze real-time traffic data to optimize signal timings, reduce congestion, and provide intelligent navigation solutions.
#     *   **Public Safety & Surveillance:** AI-powered analytics from CCTV feeds can assist in identifying suspicious activities, managing crowds, and enhancing overall security.
#     *   **Waste Management & Environmental Monitoring:** AI helps optimize waste collection routes, monitor air and water quality, and manage energy consumption in smart buildings.
#
# **V. Challenges and Considerations**
#
# While India's AI journey is marked by immense promise, it is not without its hurdles. Addressing these challenges is crucial for sustainable and equitable growth.
#
# *   **A. Data Privacy & Security:** With the immense volume of data being generated and processed, ensuring robust data protection is paramount. The ongoing implementation of the **Digital Personal Data Protection Act (DPDP Act)** is a significant step, but continuous efforts are needed to ensure ethical handling, secure storage, and prevent misuse of personal data.
# *   **B. Ethical AI & Bias:** AI models are only as unbiased as the data they are trained on. India's diverse population presents unique challenges in preventing algorithmic bias, which could lead to unfair outcomes in critical areas like credit scoring, healthcare diagnostics, or recruitment. Ensuring fairness, transparency, and accountability in AI systems is a complex but essential task.
# *   **C. Job Displacement & Skilling Gap:** The rise of automation, while increasing efficiency, raises concerns about potential job displacement in certain sectors. There is an urgent need for massive upskilling and reskilling initiatives to prepare the workforce for AI-era jobs. Bridging the gap between academic curricula and evolving industry demands is critical to ensure a future-ready workforce.
# *   **D. Infrastructure Gaps:** Despite significant progress, uneven access to high-speed internet, particularly in rural and remote areas, remains a challenge. Furthermore, the immense computational power required for advanced AI research and deployment necessitates more robust infrastructure, including high-performance computing, cloud computing capabilities, and data centers.
# *   **E. Regulatory Framework:** Developing agile and forward-looking regulations that foster innovation while simultaneously ensuring safety, ethics, and consumer protection is a delicate balancing act. India needs a comprehensive and adaptable regulatory framework that can keep pace with rapid technological advancements and harmonize with international AI policies.
# *   **F. Digital Divide:** Ensuring that the benefits of AI reach all segments of society, not just urban centers or the tech-savvy elite, is a significant challenge. Addressing language barriers in AI applications and developing solutions that cater to diverse socio-economic backgrounds is crucial to prevent the digital divide from widening.
#
# **VI. The Road Ahead: India's AI Future**
#
# Looking forward, India's trajectory in the AI landscape is set to be one of significant global influence.
#
# *   **A. Global AI Leadership:** With its unique advantages, India has the potential to become a major global AI innovation hub, not just consuming but also exporting cutting-edge AI solutions tailored for diverse global needs.
# *   **B. "AI for Social Good":** India's commitment to "AI for All" will continue to drive the development of AI solutions specifically aimed at solving its unique socio-economic challenges, such as alleviating poverty, improving healthcare access, enhancing education, and promoting sustainable development.
# *   **C. Enhanced Collaboration:** Strengthening ties between government bodies, industry leaders, academic institutions, and international partners will be key to accelerating research, fostering knowledge exchange, and tackling complex AI challenges collaboratively.
# *   **D. Continuous Talent Development:** Sustained investment in advanced AI research and specialized skill-building programs will be crucial to maintain and expand India's competitive edge in the global AI talent market.
# *   **E. Responsible Innovation:** India is poised to champion the development and deployment of ethical, secure, and inclusive AI systems, setting a global precedent for responsible innovation that prioritizes human well-being and societal benefit.
#
# **VII. Conclusion**
#
# The rise of AI in India is far more than a mere technological trend; it represents a national endeavor with the profound potential to uplift millions, drive unprecedented economic growth, and position India as a responsible and influential leader in the global AI era. From leveraging its demographic dividend and digital public infrastructure to fostering a vibrant startup ecosystem and investing strategically in R&D, India is building a robust foundation for an AI-powered future.
#
# While significant challenges related to data privacy, ethical AI, and skilling gaps remain, the concerted efforts by government, industry, and academia are geared towards navigating these complexities. The journey has just begun, and the world watches with anticipation as India harnesses the power of artificial intelligence to not only transform its own destiny but also contribute significantly to a more intelligent, inclusive, and sustainable global future. We invite you to share your thoughts on India's exciting AI journey in the comments below.
